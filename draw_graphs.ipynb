# %%
# coding: utf-8
#!/usr/bin/env python

###========================================================###
###========================================================###
###                 DRAWING GRAPHS  $ FIGURES              ###
###========================================================###
###========================================================###




import os
import matplotlib.pyplot as plt 


    
#====================================
def draw_graph_pk_msk_prk(graph_title, x_label, y_label, x_list,  y1_list, y1_legend, y2_list, y2_legend, y3_list, y3_legend, yticks_list):
    #(n, q, mt, w, m, M, sigma_1, sigma_2, sigma_3, sigma)
 
    
    # plotting the points
    plt.scatter(x_list, y1_list) 
    plt.scatter(x_list, y2_list) 
    plt.scatter(x_list, y3_list)

    
    plt.plot(x_list, y1_list, label = y1_legend) 
    plt.plot(x_list, y2_list, label = y2_legend) 
    plt.plot(x_list, y3_list, label = y3_legend)

    
    # naming the x axis 
    plt.xlabel(x_label) 
    # naming the y axis 
    plt.ylabel(y_label) 
    plt.grid(True)
    
    # giving a title to the graph 
    plt.title(graph_title) 
    plt.legend() 
    plt.xticks(x_list)
    plt.yticks(yticks_list)
    
    # function to show the plot  
    plt.savefig("pk_msk_prk_size.png", bbox_inches='tight')
    plt.show()
    
# ===========================

def draw_graph_sig_size(graph_title, x_label, y_label, x_list,  y1_list, y1_legend, y2_list, y2_legend, y3_list, y3_legend, y4_list, y4_legend, yticks_list):
    #(n, q, mt, w, m, M, sigma_1, sigma_2, sigma_3, sigma)
    """
    x_label="Number of signers"
    y_label = "Size (kB)",
    x_list=[10, 20, 30, 40]
    y1_legend = "n=40"
    y1_list = avg_keygen_time_list
    y2_legend = "n=60"
    y2_list = avg_extract_time_list
    y3_legend = "n=80"
    y3_list = avg_keygen_time_list
    y4_legend = "n=100"
    y4_list = sig_size
    """
    

    
    # plotting the points
    plt.scatter(x_list, y1_list) 
    plt.scatter(x_list, y2_list) 
    plt.scatter(x_list, y3_list)
    plt.scatter(x_list, y4_list)
    
    plt.plot(x_list, y1_list, label = y1_legend) 
    plt.plot(x_list, y2_list, label = y2_legend) 
    plt.plot(x_list, y3_list, label = y3_legend)
    plt.plot(x_list, y4_list, label = y4_legend)
    
    # naming the x axis 
    plt.xlabel(x_label) 
    # naming the y axis 
    plt.ylabel(y_label) 
    plt.grid(True)

    
    # giving a title to the graph 
    plt.title(graph_title) 
    plt.legend() 
    plt.xticks(x_list)
    plt.yticks(yticks_list)
    #plt.yticks(y2_list)
    #plt.yticks(y3_list)
    #plt.yticks(y4_list)
    
    # function to show the plot 
    #plt.show() 
    plt.savefig("sig_size.png", bbox_inches='tight')
    plt.show()
 #===================================   
def draw_graph_key_extract_time(graph_title, x_label, y_label, x_list,  y1_list, y1_legend, y2_list, y2_legend, yticks_list):
    """
    x_label="n with respect to public parameters"
    y_label = "Time (s)",
    x_list=[n=40, n=60, n=80, n=100]
    y1_legend = "Key generation time"
    y1_list = avg_keygen_time_list
    y2_legend = "Extraction time"
    y2_list = avg_extract_time_list
    """
    #(n, q, mt, w, m, M, sigma_1, sigma_2, sigma_3, sigma)
  
    # plotting the points
    plt.scatter(x_list, y1_list) 
    plt.scatter(x_list, y2_list) 
  
    
    plt.plot(x_list, y1_list, label = y1_legend) 
    plt.plot(x_list, y2_list, label = y2_legend) 

    
    # naming the x axis 
    plt.xlabel(x_label) 
    # naming the y axis 
    plt.ylabel(y_label) 

    
    # giving a title to the graph 
    plt.title(graph_title) 
    plt.legend() 
    plt.xticks(x_list)
    #plt.yticks(y1_list)
    plt.yticks(yticks_list)
    plt.grid(True)

    
    # function to show the plot 
    #plt.show() 

    plt.savefig("key_extract_time.png", bbox_inches='tight')
    plt.show()
  

  
  #=================


def draw_graph_sig_verify_link_time(graph_title, x_label, y_label, x_list,  y1_list, y1_legend, y2_list, y2_legend, y3_list, y3_legend, yticks_list):
    #(n, q, mt, w, m, M, sigma_1, sigma_2, sigma_3, sigma)
    """
    x_label="Number of signers"
    y_label = "Tiime (s)",
    x_list=[10, 20, 30, 40]
    y1_legend = "Signing time"
    y1_list = avg_sign_time_list
    y2_legend = "Verification time"
    y2_list = avg_verify_time_list
    y3_legend = "Linking time"
    y3_list = avg_link_time_list
    """
  

    
    # plotting the points
    plt.scatter(x_list, y1_list) 
    plt.scatter(x_list, y2_list) 
    plt.scatter(x_list, y3_list)
  
    
    plt.plot(x_list, y1_list, label = y1_legend) 
    plt.plot(x_list, y2_list, label = y2_legend) 
    plt.plot(x_list, y3_list, label = y3_legend)
    
    # naming the x axis 
    plt.xlabel(x_label) 
    # naming the y axis 
    plt.ylabel(y_label) 

    
    # giving a title to the graph 
    plt.title(graph_title) 
    plt.legend() 
    plt.xticks(x_list)
    plt.yticks(yticks_list)
    plt.grid(True)
    #plt.yticks(y2_list)
    #plt.yticks(y3_list)
    #plt.yticks(y4_list)
    
    # function to show the plot 
    #plt.show()
    plt.savefig("sig_verify_link_time", bbox_inches='tight')
    plt.show()

    
    
    #=============================
    
    
def draw_graph_all_times(graph_title, x_label, y_label, x_list,  y1_list, y1_legend, y2_list, y2_legend, y3_list, y3_legend, yticks_list):
    #(n, q, mt, w, m, M, sigma_1, sigma_2, sigma_3, sigma)
    """
    x_label="Number of signers"
    y_label = "Tiime (s)",
    x_list=[10, 20, 30, 40]
    y1_legend = "Key generation time"
    y1_list = avg_keygen_time_list
    y2_legend = "Extraction time"
    y2_list = avg_extract_time_list
    
    y3_legend = "Signing time"
    y3_list = avg_sign_time_list
    y4_legend = "Verification time"
    y4_list = avg_verify_time_list
    y5_legend = "Linking time"
    y5_list = avg_link_time_list
    """
    
    # draw the horizontal line
  #  for i in range(0, len(y1_list)):
        #plt.axhline(y=y1_list[i], color='gray', linestyle='--') 
    #for i in range(0, len(y2_list)):
        #plt.axhline(y=y2_list[i], color='gray', linestyle='--') 
    #for i in range(0, len(y3_list)):
        #plt.axhline(y=y3_list[i], color='gray', linestyle='--') 
    #for i in range(0, len(y4_list)):
        #plt.axhline(y=y4_list[i], color='gray', linestyle='--') 
    #for i in range(0, len(y5_list)):
        #plt.axhline(y=y5_list[i], color='gray', linestyle='--') 

    
    # plotting the points
    plt.scatter(x_list, y1_list) 
    plt.scatter(x_list, y2_list) 
    plt.scatter(x_list, y3_list)
  
    
    plt.plot(x_list, y1_list, label = y1_legend) 
    plt.plot(x_list, y2_list, label = y2_legend) 
    plt.plot(x_list, y3_list, label = y3_legend)
   
    
    # naming the x axis 
    plt.xlabel(x_label) 
    # naming the y axis 
    plt.ylabel(y_label) 

    
    # giving a title to the graph 
    plt.title(graph_title) 
    plt.legend() 
    plt.xticks(x_list)
    plt.yticks(yticks_list)
    plt.grid(True)
    #plt.yticks(y2_list)
    #plt.yticks(y3_list)
    #plt.yticks(y4_list)
    
    # function to show the plot 
    #plt.show()
    plt.savefig("all_times", bbox_inches='tight')
    plt.show()

# %%
public_parameters_list=[40, 60, 80, 100]  # n=40, n=60, n=80, n=100
keygen_time_list=[4, 19, 117, 153]     # w.r.t n=40, n=60, n=80, n=100
extract_time_list=[318, 2115, 9773, 23861]   # w.r.t n=40, n=60, n=80, n=100
yticks=[318, 2115, 9773, 23861]

40,4,378
60,19,2115
80,117,9773
100,153,23861


#40,57.839228678000836,6087.130561600001
#60,194.67710420899857,30260.805987661
#80,1105.3691388830048,122128.494183256
#100,1635.169946554,332921.11416195304


draw_graph_key_extract_time(graph_title = " Key generation time and Extraction time",
               x_label = "Public parameters (defined by $n$)", 
               y_label = "Time (s)",  
               x_list  = public_parameters_list,
               y1_list = keygen_time_list,
               y1_legend="Key generation time",
               y2_list = extract_time_list,
               y2_legend="Extraction time",
               yticks_list=yticks)

# %%
number_of_signers_list=[10,20,30,40]

size_signature_list_pp1=[139, 277, 415, 553] # w.r.t 10, 20, 30, 40
size_signature_list_pp2=[250, 493, 737, 981] # w.r.t 10, 20, 30, 40
size_signature_list_pp3=[403, 791, 1180, 1568] # w.r.t 10, 20, 30, 40
size_signature_list_pp4=[613, 1198, 1784, 2369] # w.r.t 10, 20, 30, 40
yticks=[139,  415,  250,  981,791, 1180,1568, 613,  1784,  2369]


40,10,139
40,20,277
40,30,415
40,40,553

60,10,250
60,20,493
60,30,737
60,40,981

80,10,403
80,20,791
80,30,1180
80,40,1568

100,10,613
100,20,1198
100,30,1784
100,40,2369





draw_graph_sig_size(graph_title = "Signature sizes",
               x_label = "Number of ring members", 
               y_label = "Size (kB)", 
               x_list  = number_of_signers_list,
               y1_list = size_signature_list_pp1,
               y1_legend = "$pp_1$",
               y2_list = size_signature_list_pp2,
               y2_legend = "$pp_2$",
               y3_list = size_signature_list_pp3,
               y3_legend = "$pp_3$",
               y4_list = size_signature_list_pp4,
               y4_legend = "$pp_4$",
               yticks_list=yticks)

# %%
number_of_signers_list=[10,20,30,40]

public_parameters_list=[40, 60, 80, 100]  # n=40, n=60, n=80, n=100


# for 10 signers
sign_time_list_10=[1.9, 4.6, 21.9, 45.1 ] # w.r.t n=40, 60, 80, 100

verify_time_list_10=[ 0.5, 1.4, 5.1, 9.9] # w.r.t n=40, 60, 80, 100

link_time_list_10=[1.1, 2.9, 10.3, 19.9] # w.r.t n=40, 60, 80, 100
yticks=[  21.9, 45.1 , 0.5,  5.1,   2.9, 10.3, 19.9 ]


40,10,1.9,0.5,1.1
40,20,2.5,1,1.9
40,30,3.1,1.5, 3.1
40,40,3.7,1.9,3.8

60,10,4.6,1.4, 2.9
60,20,5.5,2.7,5.3
60,30,26.6,3.9,7.7
60,40,35.4,5.3,10.7

80,10,21.9,5.1,10.3
80,20,60.3,10.1,20.1
80,30,26.4,14.1,28
80,40,33.8,19.9,40


100,10,45.1,9.9, 19.9
100,20,126.9,19.2,38.2
100,30,142.1,28.7,57.4
100,40,245.4,38.0,76.4



#40,10,22.875240600000325,6.943610423000791,0.00034539500120445155
#40,20,60.44201992099988,13.00956162699913,0.0003841010002361145
#40,30,61.24285124200105,19.534095064000212,0.000369724000847782
#40,40,156.75304100599897,26.391176537999854,0.0003333160002512159

#60,10,142.66381255500164,21.90617829799885,0.001964687995496206
#60,20,153.037535079995,43.614014222999685,0.0003968050004914403
#60,30,408.97486780399777,73.18268802300008,0.0004823560011573136
#60,40,149.47904311700404,83.29412266099826,0.0003973749990109354

#80,10,303.3811688819842,83.33641711098608,0.004431073000887409
#80,20,485.2740772169782,145.02512797398958,0.003831225010799244
#80,30,1022.3541688609985,223.44809483998688,0.0025949380069505423
#80,40,497.91669965800247,298.58205520600313,0.0019225750002078712

#100,10,495.9259666139842,170.2992167030461,0.003613494976889342
#100,20,726.6381671770359,334.2643216350116,0.004370907961856574
#100,30,974.4143848560052,530.9420248620445,0.003850025008432567
#100,40,4663.942621881026,667.5351848260034,0.0032996120280586183



draw_graph_sig_verify_link_time(graph_title="Signing time, Verification time and Linking time (for $10$ signers)",
                                x_label="Public parameters",
                                y_label="Time (s)",
                                x_list=public_parameters_list,
                                y1_list=sign_time_list_10, 
                                y1_legend="Signing time (for 10 signers)",
                                y2_list=verify_time_list_10, 
                                y2_legend="Verification time (for 10 signers)",
                                y3_list=link_time_list_10, 
                                y3_legend = "Linking time (for 10 signers)",
                               yticks_list=yticks)

# %%
public_parameters_list=["$pp_1$", "$pp_2$", "$pp_3$", "$pp_4$"]  # n=40, n=60, n=80, n=100
public_key_size_list=[253, 713, 1550, 2905] # w.r.t n=40, n=60, n=80, n=100
secret_key_size_list=[287, 804, 1740, 3254] # w.r.t n=40, n=60, n=80, n=100
private_key_size_list=[299, 782, 1580, 2770] # w.r.t n=40, n=60, n=80, n=100
yticks=[253, 713,  1550, 1740, 2770, 2905, 3254]

40,253,287,299
60,713,804,782
80,1550,1740,1580
100,2905,3254,2770


draw_graph_pk_msk_prk(graph_title="Public key sizes, Master secret key sizes and Private key sizes",
                      x_label="Public parameters",
                      y_label="Size (kB)",
                      x_list=public_parameters_list,
                      y1_list=public_key_size_list,
                      y1_legend="Public key size",
                      y2_list=secret_key_size_list,
                      y2_legend="Master secret key size",
                      y3_list=private_key_size_list,
                      y3_legend = "Private key size",
                      yticks_list=yticks)

# %%
number_of_signers_list=[10,20,30,40]

public_parameters_list=[40, 60, 80, 100]  # n=40, n=60, n=80, n=100


# For 10 signers
sign_time_list=[1.9, 4.6, 21.9, 45.1 ] # w.r.t n=40, 60, 80, 100
verify_time_list=[ 0.5, 1.4, 5.1, 9.9] # w.r.t n=40, 60, 80, 100
link_time_list=[1.1, 2.9, 10.3, 19.9] # w.r.t n=40, 60, 80, 100


# For 40 signers
sign_time_list_40=[3.7, 27.4, 33.8, 185.4] # w.r.t n=40, 60, 80, 100
verify_time_list_40=[1.9, 5.3, 19.9, 38] # w.r.t n=40, 60, 80, 100
link_time_list_40=[3.8, 10.7, 40, 76.4] # w.r.t n=40, 60, 80, 100




40,10,1.9,0.5,1.1
40,20,2.5,1,1.9
40,30,3.1,1.5, 3.1
40,40,3.7,1.9,3.8

60,10,4.6,1.4, 2.9
60,20,5.5,2.7,5.3
60,30,26.6,3.9,7.7
60,40,35.4,5.3,10.7

80,10,21.9,5.1,10.3
80,20,60.3,10.1,20.1
80,30,26.4,14.1,28
80,40,33.8,19.9,40


100,10,45.1,9.9, 19.9
100,20,126.9,19.2,38.2
100,30,142.1,28.7,57.4
100,40,245.4,38.0,76.4

#===keygen time and extraction time
keygen_time_list=[4, 19, 117, 153]     # w.r.t n=40, n=60, n=80, n=100
extract_time_list=[318, 2115, 9773, 23861]   # w.r.t n=40, n=60, n=80, n=100
yticks=[318, 2115, 9773, 23861]

40,4,378
60,19,2115
80,117,9773
100,153,23861




#40,10,22.875240600000325,6.943610423000791,0.00034539500120445155
#40,20,60.44201992099988,13.00956162699913,0.0003841010002361145
#40,30,61.24285124200105,19.534095064000212,0.000369724000847782
#40,40,156.75304100599897,26.391176537999854,0.0003333160002512159

#60,10,142.66381255500164,21.90617829799885,0.001964687995496206
#60,20,153.037535079995,43.614014222999685,0.0003968050004914403
#60,30,408.97486780399777,73.18268802300008,0.0004823560011573136
#60,40,149.47904311700404,83.29412266099826,0.0003973749990109354

#80,10,303.3811688819842,83.33641711098608,0.004431073000887409
#80,20,485.2740772169782,145.02512797398958,0.003831225010799244
#80,30,1022.3541688609985,223.44809483998688,0.0025949380069505423
#80,40,497.91669965800247,298.58205520600313,0.0019225750002078712

#100,10,495.9259666139842,170.2992167030461,0.003613494976889342
#100,20,726.6381671770359,334.2643216350116,0.004370907961856574
#100,30,974.4143848560052,530.9420248620445,0.003850025008432567
#100,40,4663.942621881026,667.5351848260034,0.0032996120280586183



draw_graph_all_times(graph_title="Comparison of running time of algorithms in IdLRS",
                                x_label="Public parameters $pp_i$ (defined by $n$)",
                                y_label="Time (s)",
                                x_list=public_parameters_list,
                                y1_list = keygen_time_list,
                                y1_legend="Key generation time",
                                y2_list = extract_time_list,
                                y2_legend="Extraction time", 
                                y3_list=sign_time_list_40, 
                                y3_legend="Signing time (w.r.t. 40 signers)",
                               yticks_list= yticks)

# %%
if __name__ == "__main__":
    print("The main section has been started")
    print("*********************************")

# %%
import matplotlib.pyplot as plt

public_parameters_list=["$pp_1$", "$pp_2$", "$pp_3$", "$pp_4$"]  # n=40, n=60, n=80, n=100
public_key_size_list_real=[253, 713, 1550, 2905] # w.r.t n=40, n=60, n=80, n=100
secret_key_size_list_real=[287, 804, 1740, 3254] # w.r.t n=40, n=60, n=80, n=100
private_key_size_list_real=[299, 782, 1580, 2770] # w.r.t n=40, n=60, n=80, n=100

public_key_size_list_theoretical=[265, 740, 1600, 2991] # w.r.t n=40, n=60, n=80, n=100
secret_key_size_list_theoretical=[336, 940, 2034, 3802] # w.r.t n=40, n=60, n=80, n=100
private_key_size_list_theoretical=[310, 805, 1620, 2826] # w.r.t n=40, n=60, n=80, n=100





  
#plt.plot(Pub, Unemployment_Rate, color='red', marker='o')
plt.plot(public_parameters_list, public_key_size_list_real, marker='o', label="Public key size (Exp.)")
plt.plot(public_parameters_list, public_key_size_list_theoretical, marker='o', label="Public key size (Theo.)")

plt.plot(public_parameters_list, secret_key_size_list_real, marker='x', label="Master secret key size (Exp.)")
plt.plot(public_parameters_list, secret_key_size_list_theoretical, marker='x', label="Master secret key size (Theo.)")

plt.plot(public_parameters_list, private_key_size_list_real, marker='o', label="Private key size (Exp.)" )
plt.plot(public_parameters_list, private_key_size_list_theoretical, marker='o', label="Private key size (Theo.)")
plt.legend()


plt.title("Public key sizes, Master secret key sizes and Private key sizes")
plt.xlabel('Public Parameters')
plt.ylabel('Size (kB)')
plt.grid(True)
plt.savefig("pk_sk_prk_size_experiment_theoretical", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

number_of_signers_list=["$10$","$20$","$30$","$40$"]

size_signature_list_pp1_real=[139, 277, 415, 553] # w.r.t 10, 20, 30, 40
size_signature_list_pp2_real=[250, 493, 737, 981] # w.r.t 10, 20, 30, 40
size_signature_list_pp3_real=[403, 791, 1180, 1568] # w.r.t 10, 20, 30, 40
size_signature_list_pp4_real=[613, 1198, 1784, 2369] # w.r.t 10, 20, 30, 40


size_signature_list_pp1_theo=[147, 288, 429, 571] # w.r.t 10, 20, 30, 40
size_signature_list_pp2_theo=[262, 511, 760, 1008] # w.r.t 10, 20, 30, 40
size_signature_list_pp3_theo=[421, 817, 1212, 1608] # w.r.t 10, 20, 30, 40
size_signature_list_pp4_theo=[639, 1234, 1830, 2426] # w.r.t 10, 20, 30, 40






  
#plt.plot(Pub, Unemployment_Rate, color='red', marker='o')
plt.plot(number_of_signers_list, size_signature_list_pp1_real, marker='o', label="$pp_1$ (Exp.)")
plt.plot(number_of_signers_list, size_signature_list_pp1_theo, marker='o', label="$pp_1$ (Theo.)")

plt.plot(number_of_signers_list, size_signature_list_pp2_real, marker='o', label="$pp_2$ (Exp.)")
plt.plot(number_of_signers_list, size_signature_list_pp2_theo, marker='o', label="$pp_2$ (Theo.)")

plt.plot(number_of_signers_list, size_signature_list_pp3_real, marker='o', label="$pp_3$ (Exp.)")
plt.plot(number_of_signers_list, size_signature_list_pp3_theo, marker='o', label="$pp_3$ (Theo.)")

plt.plot(number_of_signers_list, size_signature_list_pp4_real, marker='o', label="$pp_4$ (Exp.)")
plt.plot(number_of_signers_list, size_signature_list_pp4_theo, marker='o', label="$pp_4$ (Theo.)")
plt.legend()


plt.title("Signature sizes")
plt.xlabel('Number of ring signers')
plt.ylabel('Size (kB)')
plt.grid(True)
plt.savefig("sig_size_experiment_theoretical", bbox_inches='tight')
plt.show()

# %%
number_of_signers_list=[10,20,30,40]

public_parameters_list=[40, 60, 80, 100]  # n=40, n=60, n=80, n=100


# For 10 signers
sign_time_list_10=[1.9, 4.6, 21.9, 45.1 ] # w.r.t n=40, 60, 80, 100
#verify_time_list_10=[ 0.5, 1.4, 5.1, 9.9] # w.r.t n=40, 60, 80, 100
#link_time_list_10=[1.1, 2.9, 10.3, 19.9] # w.r.t n=40, 60, 80, 100

# For 40 signers
sign_time_list_40=[3.7, 27.4, 33.8, 185.4]
verify_time_list_40=[1.9, 5.3, 19.9, 38] # w.r.t n=40, 60, 80, 100
link_time_list_40=[3.8, 10.7, 40, 76.4] # w.r.t n=40, 60, 80, 100

#===keygen time and extraction time
keygen_time_list=[4, 19, 117, 153]     # w.r.t n=40, n=60, n=80, n=100
extract_time_list=[318, 2115, 9773, 23861]   # w.r.t n=40, n=60, n=80, n=100


plt.title('Comparison of running time of algorithms in IdLRS', fontsize=14)
plt.xlabel('Public parameters (defined by $n$)', fontsize=14)
plt.ylabel('Time (s)', fontsize=14)
plt.grid(True)

plt.plot(public_parameters_list, sign_time_list_40, color='red', marker='o')
#plt.plot(public_parameters_list, verify_time_list,  color='green', marker='x')
#plt.plot(public_parameters_list, link_time_list,  color='yellow', marker='x')
plt.plot(public_parameters_list, keygen_time_list, color='blue', marker='x')
plt.plot(public_parameters_list, extract_time_list, color='orange', marker='o')
#plt.title('Unemployment Rate Vs Year', fontsize=14)
#plt.xlabel('verify_time_list', fontsize=14)

#plt.grid(True)



plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


40,10,1.9,0.5,1.1
40,20,2.5,1,1.9
40,30,3.1,1.5, 3.1
40,40,3.7,1.9,3.8

60,10,4.6,1.4, 2.9
60,20,5.5,2.7,5.3
60,30,18.6,3.9,7.7
60,40,27.4,5.3,10.7

80,10,11.9,5.1,10.3
80,20,15.3,10.1,20.1
80,30,26.4,14.1,28
80,40,33.8,19.9,40


100,10,45.1,9.9, 19.9
100,20,126.9,19.2,38.2
100,30,142.1,28.7,57.4
100,40,185.4,38.0,76.4





labels = ['$pp_1$', '$pp_2$', '$pp_3$', '$pp_4$']



# For 10 signers
sign_time_list=[1.9, 4.6, 21.9, 45.1 ] # w.r.t n=40, 60, 80, 100
verify_time_list=[ 0.5, 1.4, 5.1, 9.9] # w.r.t n=40, 60, 80, 100
link_time_list=[1.1, 2.9, 10.3, 19.9] # w.r.t n=40, 60, 80, 100



# For 40 signers
sign_time_list_40=[3.7, 27.4, 33.8, 185.4] # w.r.t n=40, 60, 80, 100
verify_time_list_40=[1.9, 5.3, 19.9, 38] # w.r.t n=40, 60, 80, 100
link_time_list_40=[3.8, 10.7, 40, 76.4] # w.r.t n=40, 60, 80, 100



#===keygen time and extraction time
keygen_time_list=[4, 19, 117, 153]     # w.r.t n=40, n=60, n=80, n=100
extract_time_list=[318, 2115, 9773, 23861]   # w.r.t n=40, n=60, n=80, n=100





x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, sign_time_list_40, width, label='Signing time (for 40 signers)')
rects2 = ax.bar(x - width/2, verify_time_list_40, width, label='Verification time (for 40 signers)')
rects3 = ax.bar(x + width/2, link_time_list_40, width, label='Linking time (for 40 signers)')
rects4 = ax.bar(x + width, keygen_time_list, width, label='Key generation time')
#rects5 = ax.bar(x + 3*width/2, extract_time_list, width, label='Extraction time')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Time (s)')
ax.set_xlabel('Public parameters')
ax.set_title('Comparison of running times (for 40 signers)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.grid(True)
#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.savefig("compare_times_40", bbox_inches='tight')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


40,10,1.9,0.5,1.1
40,20,2.5,1,1.9
40,30,3.1,1.5, 3.1
40,40,3.7,1.9,3.8

60,10,4.6,1.4, 2.9
60,20,5.5,2.7,5.3
60,30,18.6,3.9,7.7
60,40,27.4,5.3,10.7

80,10,11.9,5.1,10.3
80,20,15.3,10.1,20.1
80,30,26.4,14.1,28
80,40,33.8,19.9,40


100,10,45.1,9.9, 19.9
100,20,126.9,19.2,38.2
100,30,142.1,28.7,57.4
100,40,185.4,38.0,76.4





labels = ['$pp_1$', '$pp_2$', '$pp_3$', '$pp_4$']



# For 10 signers
sign_time_list=[1.9, 4.6, 21.9, 45.1 ] # w.r.t n=40, 60, 80, 100
verify_time_list=[ 0.5, 1.4, 5.1, 9.9] # w.r.t n=40, 60, 80, 100
link_time_list=[1.1, 2.9, 10.3, 19.9] # w.r.t n=40, 60, 80, 100



# For 40 signers
sign_time_list_40=[3.7, 27.4, 33.8, 185.4] # w.r.t n=40, 60, 80, 100
verify_time_list_40=[1.9, 5.3, 19.9, 38] # w.r.t n=40, 60, 80, 100
link_time_list_40=[3.8, 10.7, 40, 76.4] # w.r.t n=40, 60, 80, 100



#===keygen time and extraction time
keygen_time_list=[4, 19, 117, 153]     # w.r.t n=40, n=60, n=80, n=100
extract_time_list=[318, 2115, 9773, 23861]   # w.r.t n=40, n=60, n=80, n=100





x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, sign_time_list_10, width, label='Signing time (for 10 signers)')
rects2 = ax.bar(x - width/2, verify_time_list_10, width, label='Verification time (for 10 signers)')
rects3 = ax.bar(x + width/2, link_time_list_10, width, label='Linking time (for 10 signers)')
rects4 = ax.bar(x + width, keygen_time_list, width, label='Key generation time')
#rects5 = ax.bar(x + width/5, extract_time_list_log, width, label='Extraction time')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Time (s)')
ax.set_xlabel('Public parameters')
ax.set_title('Comparison of running times (for 10 signers)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.grid(True)
#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.savefig("compare_times_10", bbox_inches='tight')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np


40,10,1.9,0.5,1.1
40,20,2.5,1,1.9
40,30,3.1,1.5, 3.1
40,40,3.7,1.9,3.8

60,10,4.6,1.4, 2.9
60,20,5.5,2.7,5.3
60,30,18.6,3.9,7.7
60,40,27.4,5.3,10.7

80,10,11.9,5.1,10.3
80,20,15.3,10.1,20.1
80,30,26.4,14.1,28
80,40,33.8,19.9,40


100,10,45.1,9.9, 19.9
100,20,126.9,19.2,38.2
100,30,142.1,28.7,57.4
100,40,185.4,38.0,76.4





labels = ['$pp_1$', '$pp_2$', '$pp_3$', '$pp_4$']



# For 10 signers
sign_time_list=[1.9, 4.6, 21.9, 45.1 ] # w.r.t n=40, 60, 80, 100
verify_time_list=[ 0.5, 1.4, 5.1, 9.9] # w.r.t n=40, 60, 80, 100
link_time_list=[1.1, 2.9, 10.3, 19.9] # w.r.t n=40, 60, 80, 100



# For 40 signers
sign_time_list_40=[3.7, 27.4, 33.8, 185.4] # w.r.t n=40, 60, 80, 100
verify_time_list_40=[1.9, 5.3, 19.9, 38] # w.r.t n=40, 60, 80, 100
link_time_list_40=[3.8, 10.7, 40, 76.4] # w.r.t n=40, 60, 80, 100



#===keygen time and extraction time
keygen_time_list=[4, 19, 117, 153]     # w.r.t n=40, n=60, n=80, n=100
extract_time_list=[318, 2115, 9773, 23861]   # w.r.t n=40, n=60, n=80, n=100





x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width, sign_time_list_40, width, label='Signing time (for 40 signers)')
rects2 = ax.bar(x - width/2, verify_time_list_40, width, label='Verification time (for 40 signers)')
rects3 = ax.bar(x + width/2, link_time_list_40, width, label='Linking time (for 40 signers)')
rects4 = ax.bar(x + width, keygen_time_list, width, label='Key generation time')
rects5 = ax.bar(x + 3*width/2, extract_time_list, width, label='Extraction time')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Time (s)')
ax.set_xlabel('Public parameters')
ax.set_title('Comparison of running times (for 40 signers)')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()
plt.grid(True)
#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()
plt.savefig("compare_times_all", bbox_inches='tight')
plt.show()
